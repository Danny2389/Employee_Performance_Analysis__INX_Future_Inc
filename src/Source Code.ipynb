# %%
# Importing relevant libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
# Importing data from the dataset
Emp = pd.read_excel(r'E:\Projects\DATASCIENCE & AI\Internship Projects\Employee-Performance-Analysis--INX-Future-Inc\data\processed\INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xlsx')

# %%
#Reading the first 3 rows
Emp.head(10)
# Out:
#   EmpNumber  Age  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32    Male           Marketing        Single            Sales
# 1  E1001006   47    Male           Marketing        Single            Sales
# 2  E1001007   40    Male       Life Sciences       Married            Sales
# 3  E1001009   41    Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60    Male           Marketing        Single            Sales
# 5  E1001011   27    Male       Life Sciences      Divorced      Development
# 6  E1001016   50    Male           Marketing       Married            Sales
# 7  E1001019   28  Female       Life Sciences        Single      Development
# 8  E1001020   36  Female       Life Sciences       Married      Development
# 9  E1001021   38  Female       Life Sciences        Single      Development
#
#              EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0       Sales Executive           Travel_Rarely                10
# 1       Sales Executive           Travel_Rarely                14
# 2       Sales Executive       Travel_Frequently                 5
# 3               Manager           Travel_Rarely                10
# 4       Sales Executive           Travel_Rarely                16
# 5             Developer       Travel_Frequently                10
# 6  Sales Representative           Travel_Rarely                 8
# 7             Developer           Travel_Rarely                 1
# 8             Developer              Non-Travel                 8
# 9             Developer           Travel_Rarely                 1
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# 1                  4  ...                            4
# 2                  4  ...                            3
# 3                  4  ...                            2
# 4                  4  ...                            4
# 5                  2  ...                            3
# 6                  4  ...                            4
# 7                  2  ...                            4
# 8                  3  ...                            1
# 9                  3  ...                            4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                          10                      1                   3
# 5                           9                      4                   2
# 6                           4                      2                   3
# 7                          10                      4                   3
# 8                          10                      2                   3
# 9                          10                      4                   4
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
# 5                             9                             7
# 6                             2                             2
# 7                             7                             7
# 8                             8                             7
# 9                             1                             0
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       0                     8         No                  3
# 1                       1                     7         No                  3
# 2                       1                    12         No                  4
# 3                      12                     6         No                  3
# 4                       2                     2         No                  3
# 5                       1                     7         No                  4
# 6                       2                     2         No                  3
# 7                       3                     7        Yes                  3
# 8                       0                     5         No                  3
# 9                       0                     0         No                  3
#
# [10 rows x 28 columns]

# %% [markdown]
# ##  Department Wise Performance.

# %%
# check for unique department in dataset
Emp["EmpDepartment"].value_counts()
# Out:
# EmpDepartment
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: count, dtype: int64

# %% [markdown]
# - It can thus be deduced that the Sales department has the largest number of workforce, and Data Science the lowest.

# %%
# Group by department and find which department has the highest performance rating
Emp.groupby("EmpDepartment")['PerformanceRating'].mean()
# Out:
# EmpDepartment
# Data Science              3.050000
# Development               3.085873
# Finance                   2.775510
# Human Resources           2.925926
# Research & Development    2.921283
# Sales                     2.860590
# Name: PerformanceRating, dtype: float64

# %% [markdown]
# #### Important observations:
#
# - Performance rating for employees in the Data Science department is highest.
#
# - Performance rating for employees in the Sales department is the lowest.
# - The number of employees is 1200

# %% [markdown]
# ## Top 3 important factors effecting Employee Performnace

# %%
col=list(Emp)
col.remove('EmpNumber')

# %%
col=list(Emp)
col.remove('PerformanceRating')

# %% [markdown]
# - Removed EmpNumber and PerformanceRating features, because it was not included in our Predictors and so, it will match the index with the RandomForestclassifier Feature Importance to calculate.

# %%
# Add this code in a new cell before the feature importance calculation
from sklearn.ensemble import RandomForestClassifier

# Create and train the Random Forest Classifier
RFC = RandomForestClassifier(n_estimators=100, random_state=42)

# Prepare the features (X) and target (y)
X = Emp.drop(['EmpNumber', 'PerformanceRating'], axis=1)
y = Emp['PerformanceRating']

# Handle categorical variables
categorical_columns = X.select_dtypes(include=['object']).columns
for column in categorical_columns:
    X[column] = le.fit_transform(X[column])

# Fit the model
RFC.fit(X, y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Feature Importance
col.remove('EmpNumber')  # Remove 'EmpNumber' from the list of columns
featimp=pd.DataFrame(data=RFC.feature_importances_*100.0,columns=["GiniValue"])
featimp.index=col
featimp.sort_values(["GiniValue"],axis=0,ascending=False,inplace=True)
print(featimp.head())
# Out:
#                               GiniValue
# EmpLastSalaryHikePercent      21.471172
# EmpEnvironmentSatisfaction    21.422821
# YearsSinceLastPromotion        9.337431
# ExperienceYearsInCurrentRole   4.044623
# EmpDepartment                  3.934062

# %% [raw]
#                          GiniValue
# EmpLastSalaryHikePercent    21.190817
# EmpEnvironmentSatisfaction  19.333486
# YearsSinceLastPromotion      9.569725
# EmpJobRole                   4.324786
# EmpHourlyRate                3.900271

# %% [markdown]
# - Using the feature importance method on our classifier, we can infer that the feature which has the highest percentage affects the performance rating.

# %% [markdown]
# ### The three most important factors effecting the performance of an employee listed below:
#
#  - EmpLastSalaryHikePercent  ---    21.19
#  - EmpEnvironmentSatisfaction---    19.33
#  - YearsSinceLastPromotion   ---    9.56
